# %%
import pandas as pd
import numpy as np
import os
import csv
from datetime import datetime
from datetime import timedelta
from bs4 import BeautifulSoup, NavigableString, Tag

# %%
#pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
# Ejecutando el código comentado sale una pestaña de más y un warning
#options = webdriver.ChromeOptions()
#options.add_argument('user-agent = Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.84 Safari/537.36')
#driver = webdriver.Chrome(chrome_options=options)
#driver.get("https://genealogy.math.ndsu.nodak.edu/")

options_chrome = webdriver.ChromeOptions()
driver = webdriver.Chrome(options = options_chrome)
driver.get("https://genealogy.math.ndsu.nodak.edu/")

# %%
# Clicar para la búsqueda avanzada en "Advanced Search"
advance_search = driver.find_element(By.XPATH, '//a[@href="search.php"]')
advance_search.click()

# %%
given_name_search = driver.find_element(By.ID, 'given_name')
given_name_search.send_keys("Ma")

# %%
subject_search = driver.find_element(By.XPATH, '//option[@value="62"]')
subject_search.click()

# %%
country_search = driver.find_element(By.ID, 'country')
country_search.send_keys("Spain" + Keys.ENTER)

# %%
# Clicar para la búsqueda avanzada en "Advanced Search"
advance_search = driver.find_element(By.XPATH, '//a[@href="search.php"]')
advance_search.click()

# Rellenar los campos necesarios y hacer enter
given_name_search = driver.find_element(By.ID, 'given_name')
given_name_search.send_keys("Ma")

subject_search = driver.find_element(By.XPATH, '//option[@value="62"]')
subject_search.click()

country_search = driver.find_element(By.ID, 'country')
country_search.send_keys("Spain" + Keys.ENTER)

# %%
#cargamos el contenido (ya se podría cerrar la pestaña)
soup = BeautifulSoup(driver.page_source)

# %%
main_content = soup.find(id='mainContent').table
authors_searched = main_content.find_all('tr')
#print(authors_searched)

# %%
import re

# función que dada una lista de autores extraída de la búsqueda devuelve sus ids
# para luego hacer peticiones con cada id a https://genealogy.math.ndsu.nodak.edu/id.php?id=<id>
# y de ahí extraer la info
def authors_ids(authors_searched):
    ids = []
    for author in authors_searched:
        link = author.find('a').get('href')
        id = re.search('id=(.*)', link).group(1)
        ids.append(id)
    return ids

# %%
print(authors_ids(authors_searched))
# Out:
# ['114820', '85887', '239061', '136990', '121244', '37085', '115266', '217681', '173915', '206706', '160878', '165733', '261653', '144477', '136870', '200109', '180529', '177769', '222235', '104710', '271938', '241175', '196017', '203114', '171371', '24777', '256541', '112046', '124893', '131537', '85885', '216492', '197949', '213317', '21687', '108633', '158364', '180531', '138092', '199422', '197436', '101777', '250439', '96548', '238585', '209920', '180535', '53102', '178956', '279210', '172935', '129162', '96376', '158906', '278737', '199427', '58241', '93372', '267502', '123100', '203207', '141839', '181976', '129857', '137101', '233486', '232144', '153603', '143877', '138115', '44662', '62755', '192777', '136720', '44847', '197004', '114779', '152235', '189190', '150740', '107880', '53012', '72665', '280305', '194391', '184791', '62228', '138490', '139639', '93577', '240118', '261978', '198139', '200351', '203115', '158365', '185826', '264298', '271091', '37098', '114075', '172822', '145278', '135739', '198446', '199421', '176101', '184517', '113145', '253873', '37089', '161078', '96123', '162688', '66308', '115274', '233408', '248298', '254991', '144045', '157253', '158657', '87697', '150165', '138032', '118432', '53034', '93051', '94517', '210644', '116338', '199424', '165980', '229561', '117237', '44688', '138850', '188489', '93947', '144084', '254552', '152506', '60137', '146489', '145931', '136049', '138389', '196765', '231578', '179528', '180030', '178576', '138540', '56999', '111477', '88356', '211096', '55328', '93505', '36546', '210659', '227763', '267503', '36308', '213602', '137925', '265258', '265418', '91479', '134169', '138026', '138027', '138013', '170689', '37088', '230333', '234494', '93354', '91491', '213528', '100463', '163316', '267504', '177995', '104342', '189200', '154689', '213333', '115291', '151638', '68822', '183715', '267506', '210647', '193137', '100450', '213334', '201724', '104563', '187460', '181112', '181110', '173437', '24800', '155733', '227764', '135378', '217686', '151211', '220222', '96530', '139608', '137969', '212721', '137980', '88594', '152893', '36557', '186877', '69805', '267677', '210646', '185499', '94474', '242783', '136202', '221825', '137112', '76352', '179910', '104547', '189644', '109013', '138690', '272967', '188495', '76805', '88595', '197710', '258065', '170531', '166032', '146045', '209781', '35706', '271972', '178962', '187974', '178501', '131911', '137983', '93926', '213139', '217608', '97946', '114778', '244090', '180190', '88366', '146476', '110473', '162072', '45070', '199492', '139572', '55631', '262146', '107881', '162716', '138671', '96573', '9169', '185090', '182173', '95703', '139832', '253340', '158032', '173584', '115608', '13969', '94481', '135422', '198274', '147176', '151797', '162932', '151512', '135424', '122530', '20052', '101755', '69352', '94030', '235037', '88101', '250436', '153602', '73363', '139481', '91532', '212380', '51617', '153817', '114818', '138544', '96377', '138409', '199425', '101750', '50872', '138767', '228631', '107960', '135735', '135419', '94724', '174889', '142843', '120842', '179724', '232446', '138340', '227705', '137113', '116820', '194657', '93731', '279337', '104516', '180038', '101593', '161417', '162563', '128546', '199433', '79777', '127405', '138405', '160252', '93467', '206707', '204510', '178828', '49674', '170548', '171261', '51615', '212749', '93322', '198736', '179768', '242909', '68823', '274333', '172823', '24475', '181545', '170530', '202647', '271300', '171298', '152155', '274969', '189227', '84072', '159850', '93565', '93274', '248033', '255157', '203109', '169103', '17607', '139796', '134916', '37065', '111397', '269168', '139365', '200479', '151643', '21681', '272125', '195767', '274545', '164424', '188486', '127406', '146486', '188249', '261011', '63710', '211441', '211441', '169194', '210642', '280303', '270087', '141641', '95695', '38584', '134429', '165945', '210634', '135727', '219281', '274700', '17849 ...

# %%
def authors_information(authors_id):
    """
    Realiza web scraping en las pestañas de los autores
    con id en 'authors_id'.
    
    Para cada id se scrapea la página de ese autor. Mediante las
    funciones principales de BeautifulSoup y las expresiones
    regulares, se van guardando, en este orden: nombre, universidad,
    año, pais, titulo, tutores y estudiantes.
    Finalmente, se crea una lista con los valores de estos campos y
    se añade a la lista 'information'.
    
    Parámetros:
        authors_id: lista de los ids de los autores obtenidos según
        la búsqueda

    Devuelve:
        information: lista anidada, en cada una la información de un autor/a.
    """
    #information = [] #Para CSV
    data = {}
    data['Mathematicians'] = []
    for identificador in authors_id:
        # LECTURA DE LA PÁGINA
        urls = driver.get("https://genealogy.math.ndsu.nodak.edu/id.php?id="+identificador)
        soup = BeautifulSoup(driver.page_source)

        # WEB SCRAPING
        main_content2 = soup.find(id='mainContent')
        
        # Nombre autor/autora
        nombre = main_content2.find('h2').get_text().strip() #strip() elimina los espacios en blanco al inicio y al final
        
        # Universidad
        universidad = main_content2.find_next('span').find_next('span').get_text()
        
        # Año de publicación de la tesis
        año = main_content2.find('span').get_text()
        año = ''.join(re.findall(r"\d{4}$", año))
        
        # País
        if main_content2.find('img'):
            pais = main_content2.find('img').get('title')
        else:
            pais = ''
            
        for div in range(0, len(main_content2.find_all('div'))):
            # Título de la tesis
            if div==3:
                # PRIMERA OPCIÓN
                #titulo = main_content2.find_all('div')[div].find_next('span').find_next('span').get_text().strip()
                # SEGUNDA OPCIÓN
                titulo = ''.join([i if type(i)==NavigableString else '' for i in main_content2.find_all('div')[3].contents[2].contents]).strip()
            # Asignatura
            if div == 4:
                try:
                    asignatura = main_content2.find_all('div')[div].get_text().split(r":", 1)[1].strip()
                except:
                    asignatura=''

        # Tutor/Tutores
        
        advisor_text = re.search(r'Advisor.*',main_content2.get_text())
        if advisor_text is not None:
            advisor_text = advisor_text.group(0)
            advisors_pre = re.split(r"No students known.", advisor_text)[0]
            advisors = re.split(r"Advisor: |Advisor \d: ",advisors_pre)[1:]
        else:
            advisors =[]

        # Estudiantes
        students = []
        if main_content2.table != None:
            students_searched = main_content2.table.find_all('a')
            for stud in students_searched:
                students.append(stud.get_text())

        # Para CSV
        #elemento = [nombre, universidad, año, pais, titulo, asignatura, advisors, students]
        #information.append(elemento)
        
        # Para JSON
        data['Mathematicians'].append({
            'Nombre': nombre,
            'Universidad': universidad,
            'Año': año,
            'País': pais,
            'Título': titulo,
            'Asignatura': asignatura,
            'Tutores': advisors,
            'Estudiantes': students
        })
    return data

# %%
urls = driver.get("https://genealogy.math.ndsu.nodak.edu/id.php?id=192777")

# %%
len(authors_searched)
# Out:
# 4239

# %%
info = authors_information(authors_ids(authors_searched[:20]))
info
# Out:
# {'Mathematicians': [{'Nombre': 'Policarpo  Abascal Fuentes',
#    'Universidad': 'Universidad de Oviedo',
#    'Año': '1998',
#    'País': 'Spain',
#    'Título': 'Compartir secretos mediante esquemas basados en codigos correctores',
#    'Asignatura': '05—Combinatorics',
#    'Tutores': ['Juan Gabriel Tena Ayuso'],
#    'Estudiantes': []},
#   {'Nombre': 'Boumediene  Abdellaoui',
#    'Universidad': 'Universidad Autónoma de Madrid',
#    'Año': '2003',
#    'País': 'Spain',
#    'Título': 'Elliptic and Parabolic Equations Related to Caffarelli-Kohn-Nirenberg Inequalities',
#    'Asignatura': '35—Partial differential equations',
#    'Tutores': ['Ireneo  Peral Alonso'],
#    'Estudiantes': ['Attar, Ahmed', 'Bentifour, Rachid', 'Miri, Sofiane']},
#   {'Nombre': 'Mohamed  Abdel-Nasser',
#    'Universidad': 'Universitat Rovira i Virgili',
#    'Año': '2016',
#    'País': 'Spain',
#    'Título': 'Development of advanced computer methods for breast cancer image interpretation through texture and temporal evolution analysis',
#    'Asignatura': '68—Computer science',
#    'Tutores': ['Antonio  Moreno'],
#    'Estudiantes': []},
#   {'Nombre': 'Lorenzo  Abellanas',
#    'Universidad': 'Universidad Complutense de Madrid',
#    'Año': '1969',
#    'País': 'Spain',
#    'Título': 'Invariancia galileana y simetrías superiores',
#    'Asignatura': '68—Computer science',
#    'Tutores': ['Alberto  Galindo Tixaire'],
#    'Estudiantes': ['Guil, Francisco',
#     'Heredero, Rafael',
#     'Martínez Alonso, Luis']},
#   {'Nombre': 'Manuel  Abellanas',
#    'Universidad': 'Universidad Complutense de Madrid',
#    'Año': '1984',
#    'País': 'Spain',
#    'Título': 'Estudio de los modelos canónicos de codimensión uno de las variedades algebraicas',
#    'Asignatura': '14—Algebraic geometry',
#    'Tutores': ['Pedro  Abellanas Cebollero'],
#    'Estudiantes': ['Claverol, Mercè',
#     'García-López, Jesús',
#     'Ramos, Pedro A.',
#     'Roanes Lozano, Eugenio']},
#   {'Nombre': 'Pedro  Abellanas Cebollero',
#    'Universidad': 'Universidad de Madrid',
#    'Año': '1941',
#    'País': 'Spain',
#    'Título': 'El problema de la curvatura íntegra en el caso de una variedad geométrica diferencial, de Hopf-Rinow, de dimensión par, completa y admitiendo una descomposición poliédrica que sea una pseudo-variedad cerrada.',
#    'Asignatura': '53—Differential geometry',
#    'Tutores': ['Tomás  Rodríguez Bachiller'],
#    'Estudiantes': ['Abellanas, Manuel',
#     'Aroca Hernández-Ros, José Manuel',
#     'Bujanda Jáuregui, María Paz',
#     'Calero-Rosillo, Gonzalo',
#     'Etayo Miqueo, José Javier',
#     'Fernández Biarge, Julio',
#     'Gómez Sánchez, Jesús',
#     'Hernández-Peñalver, Gregorio',
#     'Laita, Luis',
#     'Laplaza, Miguel',
#     'Llovet, Juan',
#     'Pérez de Vargas, Alberto',
#     'Pérez-Villamil Suárez, Hilda',
#     'Poyatos Suárez, Pedro',
#     'Recio, Tomás',
#     'Roanes-Macías, Eugenio',
#     'Romo Santos, Concepción',
#     'Roncalés Barrera, Josefina',
#     'Sánchez-Giralda, Tomás',
#     'Sancho Guimerá, Juan',
#     'Vicente Córdoba, José Luis',
#     'Viviente Mateu, José Luis']},
#   {'Nombre': 'Luis M.  Abia',
#    'Universidad': 'Universidad de Valladolid',
#    'Año': '1983',
#    'País': 'Spain',
#    'Título': 'Cuadratura mediante interpolación en métodos Galerkin no lineales',
#    'Asignatura': '65—Numerical analysis',
#    'Tutores': ['Jesús María Sanz-Serna'],
#    'Estudiantes': ['Martínez Rodríguez, Julia']},
#   {'Nombre': 'Ezequiel  Abia Zuazo',
#    'Universidad': 'Universidad Complutense de Madrid',
#    'Año': '1981',
#    'País': 'Spain',
#    'Título': 'Espacios simplecticos sobre un anillo de hermite: el grupo simplectico',
#    'Asignatura': '13—Commutative rings and algebras',
#    'Tutores': ['José Manuel  Aroca Hernández-Ros'],
#    'Estudiantes': []},
#   {'Nombre': 'Jilali  Aboui',
#    'Universidad': 'Universidad de La Laguna',
#    'Año': '1994',
#    'País': 'Spain',
#    'Título': 'Error y convergencia en aproximación racional en varias variables',
#    'Asignatura': '41—Approximations and expansions',
#    'Tutores': ['Ramón A.  Orive Rodríguez', 'Annie A. M. Cuyt'],
#    'Estudiantes': []},
#   {'Nombre': 'Árpád  Ábrahám',
#    'Universidad': 'Universitat Pompeu Fabra',
#    'Año': '2002',
#    'País': 'Spain',
#    'Título': 'Essays on Dynamic Economics',
#    'Asignatura': '91—Game theory, economics, social and behavioral sciences',
#    'Tutores': ['Albert  Marcet'],
#    'Estudiantes': ['Hauser, Christine', 'Sanchez, Juan', 'Shakhnov, Kirill']},
#   {'Nombre': 'Francisco Javier Abrisqueta-Usaola',
#    'Universidad': 'Universidad Publica de Navarra',
#    'Año': '2012',
#    'País': 'Spain',
#    'Título': 'Representaciones numéricas de estructuras de semiorden',
#    'Asignatura': '06—Order, lattices, ordered algebraic structures',
#    'Tutores': ['Esteban  Induráin', 'Margarita  Zudaire Sarobe'],
#    'Estudiantes': []},
#   {'Nombre': 'Ibraheem  Abu-Falahah',
#    'Universidad': 'Universidad Autónoma de Madrid',
#    'Año': '2012',
#    'País': 'Spain',
#    'Título': "Familias de Sistemas Ortonormales. Transferencia de Acotaci\\'on de operadores",
#    'Asignatura': '42—Fourier analysis',
#    'Tutores': ['José Luis  Torrea'],
#    'Estudiantes': []},
#   {'Nombre': 'Natalia  Accomazzo Scotti',
#    'Universidad': 'Universidad del País Vasco',
#    'Año': '2020',
#    'País': 'Spain',
#    'Título': 'Topics in harmonic analysis; commutators and directional singular integrals',
#    'Asignatura': '42—Fourier analysis',
#    'Tutores': [],
#    'Estudiantes': []},
#   {'Nombre': 'Juan A. Acebron',
#    'Universidad': 'Universidad Carlos III de Madrid',
#    'Año': '2000',
#    'País': 'Spain',
#    'Título': 'Collective behavior of coupled nonlinear oscillators (in Spanish)',
#    'Asignatura': '82—Statistical mechanics, structure of matter',
#    'Tutores': ['Luis L. Bonilla', 'Renato G.C. Spigler'],
#    'Estudiantes': ['Rodriguez-Rozas, Angel']},
#   {'Nombre': 'Primitivo Belén  Acosta-Humánez',
#    'Universidad': 'Universitat Politècnica de Catalunya',
#    'Año': '2009',
#    'País': 'Spain',
#    'Título': 'Galoisian Approach to Supersymmetric Quantum Mechanics',
#    'Asignatura': '81—Quantum Theory',
#    'Tutores': ['Juan José  Morales Ruiz', 'Jacques-Arthur  Weil'],
#    'Estudiantes': []},
#   {'Nombre': 'Miguel Ángel  Acosta Rodríguez',
#    'Universidad': 'Universidad de Las Palmas de Gran Canaria',
#    'Año': '2016',
#    'País': 'Spain',
#    'Título': 'La rendición de cuentas en el Espacio Europeo de Educación Superior: un marco para su análisis en el caso español',
#    'Asignatura': '91—Game theory, economics, social and behavioral sciences',
#    'Tutores': ['Laureano  Gonzalez-Vega'],
#    'Estudiantes': []},
#   {'Nombre': 'Maria Dolores Acosta-Vigil',
#    'Universidad': 'Universidad de Granada',
#    'Año': '1990',
#    'País': 'Spain',
#    'Título': 'Operadores que alcanzan su radio numérico\n(Numerical radius attaining operators)',
#    'Asignatura': '46—Functional analysis',
#    'Tutores': ['Rafael  Payá-Albert'],
#    'Estudiantes': ['Aguirre-Bago, Francisco', 'Ruiz Galán, Manuel']},
#   {'Nombre': 'Ibrahim  Adamou',
#    'Universidad': 'Universidad de Cantabria',
#    'Año': '2013',
#    'País': 'Spain',
#    'Título': 'Curvas y Superficies Bisectrices y Diagrama de Voronoi de una familia\nfinita de\nsemirrectas paralelas en R3',
#    'Asignatura': '14—Algebraic geometry',
#    'Tutores': ['Laureano  Gonzalez-Vega', 'Mario A. Fioravanti'],
#    'Estudiantes': []},
#   {'Nombre': 'Natividad  Adamuz Povedano',
#    'Universidad': 'Universidad de Cordoba',
#    'Año': '2016',
#    'País': 'Spain',
#    'Título': 'La investigación en Educación Matemática más allá de las Revistas Científicas: Un Estudio Cienciométrico en libros (1990-2012)',
#    'Asignatura': '97—Mathematics education',
#    'Tutores': ['Alexander  Maz Machado'],
#    'Estudiantes': []},
#   {'Nombre': 'Miguel  Adan Oliver',
#    'Universidad': 'Universidad Nacional de Educación a Distancia',
#    'Año': '2001',
#    'País': 'Spain',
#    'Título': 'Condiciones de optimalidad en programas vectoriales con convexidad generalizada',
#    'Asignatura': '90—Operations research, mathematical programming',
#    'Tutores': ['Vicente  Novo Sanjurjo'],
#    'Estudiantes': []}]}

# %%
# GUARDAR LOS DATOS EN JSON
import json
with open('mathematicians_dataset.json', 'w') as file:
    json.dump(info, file, indent=4)

# %%
with open("mathematicians_dataset.json", "r") as j:
    mydata = json.load(j)
    print(mydata)
# Out:
# {'Mathematicians': [{'Nombre': 'María del Carmen  Aguilera Morillo', 'Universidad': 'Universidad de Granada', 'Año': '2013', 'País': 'Spain', 'Título': 'Penalized estimation methods in functional data analysis', 'Asignatura': '62—Statistics', 'Tutores': ['Ana María Aguilera del Pino'], 'Estudiantes': []}, {'Nombre': 'Martín  Almuzara', 'Universidad': 'Universidad Internacional Menéndez Pelayo', 'Año': '2020', 'País': 'Spain', 'Título': 'Essays on Latent Variables in Time Series and Panel Data', 'Asignatura': '62—Statistics', 'Tutores': ['Manuel  Arellano', 'Enrique  Sentana'], 'Estudiantes': []}, {'Nombre': 'Ismael  Cabero', 'Universidad': 'Universitat Jaume I de Castellón', 'Año': '2019', 'País': 'Spain', 'Título': 'Some contributions to archetypal analysis with applications', 'Asignatura': '62—Statistics', 'Tutores': ['Irene  Epifanio'], 'Estudiantes': []}, {'Nombre': 'María Rosa  Casals', 'Universidad': 'Universidad de Cantabria', 'Año': '1988', 'País': 'Spain', 'Título': 'Contraste de hipótesis en ambiente difuso', 'Asignatura': '62—Statistics', 'Tutores': ['Pedro  Gil', 'María Ángeles  Gil'], 'Estudiantes': ['Montenegro, Manuel']}, {'Nombre': 'Matteo  Ciccarelli', 'Universidad': 'Universitat Pompeu Fabra', 'Año': '2001', 'País': 'Spain', 'Título': 'Bayesian inference in heterogeneous dynamic panel data models : three essays', 'Asignatura': '62—Statistics', 'Tutores': ['Fabio  Canova'], 'Estudiantes': []}, {'Nombre': 'María José  Del Moral Ávila', 'Universidad': 'Universidad de Granada', 'Año': '1993', 'País': 'Spain', 'Título': 'Reducción de dimensión mediante ACP: Enfoques alternativos', 'Asignatura': '62—Statistics', 'Tutores': ['Mariano José  Valderrama Bonnet'], 'Estudiantes': []}, {'Nombre': 'Manuel Angel  Dominguez-Toribio', 'Universidad': 'Universidad Carlos III de Madrid', 'Año': '1998', 'País': 'Spain', 'Título': 'Contrastes de especificación consistentes de modelos econométricos', 'Asignatura': '62—Statistics', 'Tutores': ['Miguel Angel Delgado'], 'Estudiantes': []}, {'Nombre': 'Manuel  Escabias Machuca', 'Universidad': 'Universidad de Granada', 'Año': '2002', 'País': 'Spain', 'Título': 'Reducción de dimensión en regresión logística funcional', 'Asignatura': '62—Statistics', 'Tutores': ['Ana María Aguilera del Pino'], 'Estudiantes': []}, {'Nombre': 'Manuel  Febrero-Bande', 'Universidad': 'Universidade de Santiago de Compostela', 'Año': '1995', 'País': 'Spain', 'Título': 'Modelización para la predicción en series de tiempo: Aspectos computacionales con nuevas aportaciones y aplicaciones', 'Asignatura': '62—Statistics', 'Tutores': ['Wenceslao  Gonzalez-Manteiga'], 'Estudiantes': []}, {'Nombre': 'Manuel J. Fernández', 'Universidad': 'Universidad de Oviedo', 'Año': '1991', 'País': 'Spain', 'Título': 'Contribuciones al estudio de ecuaciones en relaciones difusas', 'Asignatura': '62—Statistics', 'Tutores': ['Pedro  Gil', 'Fermín  Suárez'], 'Estudiantes': []}, {'Nombre': 'Marta  García-Bárzana', 'Universidad': 'Universidad de Oviedo', 'Año': '2016', 'País': 'Spain', 'Título': 'Estimación de modelos de regresión lineales múltiples con restricciones aleatorias lineales', 'Asignatura': '62—Statistics', 'Tutores': ['Ana  Colubi', 'Erricos John Kontoghiorghes'], 'Estudiantes': []}, {'Nombre': 'María Antonieta  Gayoso', 'Universidad': 'Universidad de Oviedo', 'Año': '2016', 'País': 'Spain', 'Título': 'Prescripción diferenciada a hombres y mujeres, ¿una cuestión de género?', 'Asignatura': '62—Statistics', 'Tutores': ['Agustín  Hidalgo-Balsera', 'Norberto  Corral'], 'Estudiantes': []}, {'Nombre': 'María Ángeles  Gil', 'Universidad': 'Universidad de Oviedo', 'Año': '1979', 'País': 'Spain', 'Título': 'Incertidumbre y utilidad', 'Asignatura': '62—Statistics', 'Tutores': ['Pedro  Gil'], 'Estudiantes': ['Casals, María Rosa', 'Cascos-Fernández, Ignacio', 'Caso, Covadonga', 'Colubi, Ana', 'Corral, Norberto', 'de la Rosa de Sáa, Sara', 'López-Díaz, Miguel', 'López-García, Hortensia', 'Lubiano, María Asunción', 'Martínez, Ignacio', 'Mo ...

# %%
# GUARDAR LOS DATOS EN CSV
import csv
headers = ['Nombre', 'Universidad', 'Año', 'País', 'Título', 'Asignatura', 'Tutores', 'Estudiantes']

# OPCIÓN 1 CSV
with open('mathematicians_dataset.csv', 'w', encoding='UTF8', newline='') as csvfile:
    for column in range(len(headers)):
        csvfile.write((headers[column]) + ";")
    csvfile.write("\n");
    for i in range(len(info)):
        for j in range(len(info[i])):
            csvfile.write(str(info[i][j]) + ";");
        csvfile.write("\n");

# %%
# OPCIÓN 2 CSV (Las dos opciones salen iguales)
with open('mathematicians_dataset2.csv', 'w', encoding='UTF8', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    writer.writerow(headers)
    writer.writerows(info)

# %%
data = pd.read_csv("mathematicians_dataset2.csv", sep=";")
print(data)
# Out:
#                                    Nombre  \
# 0  Apépé Jugeandène  Nguengue Louvouandou
# 1                           James T. Pepe
# 2                  Margaret Sullivan Pepe
# 3                     Wilfrid Dennis Pepe
# 4                           William  Pepe
# 5                         Aljoša  Peperko
# 6                     Jan A. Peperstraete
# 7                 Jose (Pepe) M. Quintana
#
#                              Universidad     Año  \
# 0              Marien Ngouabi University  2019.0
# 1  Massachusetts Institute of Technology  1972.0
# 2               University of Washington  1986.0
# 3                     Indiana University  1966.0
# 4              University of Connecticut  2007.0
# 5                University of Ljubljana  2008.0
# 6                                    NaN     NaN
# 7                  University of Warwick  1987.0
#
#                                País  \
# 0  Democratic Republic of the Congo
# 1                      UnitedStates
# 2                      UnitedStates
# 3                      UnitedStates
# 4                      UnitedStates
# 5                          Slovenia
# 6                               NaN
# 7                     UnitedKingdom
#
#                                               Título  \
# 0  Poisson structure on Weil bundle and generaliz...
# 1  Studies in Serial Learning and Saccadic Eye Mo...
# 2                                                NaN
# 3  Lebesgue Area and the Differential Geometry of...
# 4  On Some Bounded Risk Sequential Procedures for...
# 5  Spektralni radij integralskih operatorjev in s...
# 6                                                NaN
# 7                                                NaN
#
#                                   Asignatura                         Tutores  \
# 0  58—Global analysis, analysis on manifolds  ['Basile Guy Richard Bossoto']
# 1                                        NaN          ['Stephen  Grossberg']
# 2                                        NaN      ['Thomas Richard Fleming']
# 3                                        NaN           ['William P. Ziemer']
# 4                              62—Statistics         ['Nitis  Mukhopadhyay']
# 5                         47—Operator theory             ['Roman  Drnovšek']
# 6                                        NaN                     ['Unknown']
# 7                              62—Statistics                  ['Mike  West']
#
#                                          Estudiantes
# 0                                                 []
# 1                                                 []
# 2  ['Alonzo, Todd', 'Couper, David', 'Dodd, Lori'...
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6         ['Lauwereins, Rudy', 'Oosterlinck, Andre']
# 7                                                 []
